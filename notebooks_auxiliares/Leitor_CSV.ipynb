# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# ...
#   Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.3.3-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
# Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv('/home/jovyan/vlm_benchmark-feature-200-benchmark/testes_e_resultados/testes_e_resultados_300imoveis_20-10-2025/resultados_avaliacao/padrao_e_pontuacao_BIC/V5_gemini-2p5-flash_temp_0p5_teste/generation_results_com_bic_metricas.csv')
print("Gemini 2.5 Flash")

df
# Out:
# Gemini 2.5 Flash
#     Acuracia Acuracia %              Categoria  Desvio Max Negativo  \
# 0        NaN        NaN           RESUMO GERAL                  NaN
# 1        NaN        NaN           RESUMO GERAL                  NaN
# 2        NaN        NaN           RESUMO GERAL                  NaN
# 3        NaN        NaN           RESUMO GERAL                  NaN
# 4        NaN        NaN                    NaN                  NaN
# 5        NaN        NaN  CARACTERÍSTICAS GERAL                  NaN
# 6     0.4915     49.15%  CARACTERÍSTICAS GERAL                  NaN
# 7        NaN        NaN  CARACTERÍSTICAS GERAL                -14.0
# 8        NaN        NaN                    NaN                  NaN
# 9        NaN        NaN             TIPO: HOME                  NaN
# 10       NaN        NaN             TIPO: HOME                  NaN
# 11    0.2933     29.33%             TIPO: HOME                  NaN
# ...

# %%
# Lista das colunas que você quer verificar
colunas = [
    "acabamento_externo",
    "acabamento_interno",
    "cobertura",
    "esquadrias",
    "estrutura",
    "forro",
    "instalacao_eletrica",
    "instalacao_sanitaria",
    "piso",
    "revestimento_externo",
    "revestimento_interno"
]

# Remover linhas que não possuem resposta (NaN ou vazio) nessas colunas
df_filtrado = df.dropna(subset=colunas)

# Se também quiser remover strings vazias além de NaN
df_filtrado = df_filtrado[(df_filtrado[colunas] != "").all(axis=1)]

df_filtrado = df_filtrado.drop_duplicates(subset='id_anuncio')

# Salvar de volta se quiser
df_filtrado.to_csv("saida.csv", index=False)

# %%
df = pd.read_csv('/home/jovyan/vlm_benchmark-feature-200-benchmark/saida.csv')
print("500 Imóveis anotados")

df
# Out:
# 500 Imóveis anotados
#                                                    url  \
# 0    www.vivareal.com.br/imovel/casa-3-quartos-anha...
# 1    www.vivareal.com.br/imovel/sobrado-3-quartos-s...
# 2    www.vivareal.com.br/imovel/casa-3-quartos-seto...
# 3    www.vivareal.com.br/imovel/casa-3-quartos-tres...
# 4    www.vivareal.com.br/imovel/casa-3-quartos-seto...
# ..                                                 ...
# 291  www.vivareal.com.br/imovel/ponto-comercial-6-q...
# 292  www.vivareal.com.br/imovel/ponto-comercial-set...
# 293  www.vivareal.com.br/imovel/ponto-comercial-set...
# 294  www.vivareal.com.br/imovel/ponto-comercial-set...
# 295  www.vivareal.com.br/imovel/ponto-comercial-vil...
#
#                                 id_imovel  id_anuncio         tipo_imovel  \
# 0    00023474-dffe-37cb-9813-d32e8c980294  2811629951  demais construcoes
# 1    0010dc46-f9ea-387f-b2bf-c5f076ffae89  2816312120  demais construcoes
# ...
